# %%
"""19307039_刘章韬_python_homework4

 Developer:
    by liuzhangtao(ID:19307029), who can be reached on liuzht23@mail2.sysu.edu.cn
 History:
    the first version is done at @SYSU(zhuhai) 2021/5/17
"""
# Out:
# '19307039_刘章韬_python_homework4\n\n Developer:\n    by liuzhangtao(ID:19307029), who can be reached on liuzht23@mail2.sysu.edu.cn\n History:\n    the first version is done at @SYSU(zhuhai) 2021/5/17\n'

# %%
#import library

import numpy as np
import matplotlib.pyplot as plt

# %%
#4.1

fig=plt.figure(figsize=(10,10))

ax=plt.subplot()

x=np.arange(0,10,0.02)
plt.plot(x,np.sin(x))

plt.xlabel=('x')
plt.ylabel=('sin(x)')

#ax.lengend(frameon=False)

plt.xlim(0,np.pi*2)

plt.show()
